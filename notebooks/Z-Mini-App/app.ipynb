# %%
from pipelines import handle_query

# %%
# # QA TEST
#
# tests = [
#     "What is tokenization?",
#     "What is BERT?",
#     "What is machine learning?"
# ]
#
# for text in tests:
#     result = handle_query(text)
#     print("query :", text)
#     print("result:", result)
#     print("=" * 60)

# %%
# # CHAT TEST
#
# tests = [
#     "Help me understand RAG simply",
#     "Explain the difference between encoder and decoder",
#     "Give me a roadmap to learn NLP"
# ]
#
# for text in tests:
#     result = handle_query(text)
#     print("query :", text)
#     print("result:", result)
#     print("=" * 60)

# %%
tests = [
    "Search the documents for information about RAG",
    "Find the definition of tokenization in the documents",
    "Look in the files for machine learning"
]

for text in tests:
    result = handle_query(text)
    print("query :", text)
    print("result:", result)
    print("=" * 60)
# Out:
# query : Search the documents for information about RAG
# result: {'router': {'route': 'go_to_rag_pipeline', 'predicted_label': 'retrieve_generate', 'scores': {'chat': 0.20313412116664248, 'direct_qa': 0.13319039039709993, 'retrieve_generate': 0.6636754884362577}}, 'output': {'type': 'rag', 'query': 'Search the documents for information about RAG', 'answer': "RAG (Retrieval Augmented Generation) is a technique that combines information retrieval with text generation. Instead of relying only on the model's internal knowledge, RAG retrieves relevant documents and uses them as context for generation.", 'score': 0.6268529891967773, 'retrieved_chunks': [{'chunk_id': 0, 'score': 0.6268529891967773, 'text': "RAG (Retrieval Augmented Generation) is a technique that combines information retrieval with text generation. Instead of relying only on the model's internal knowledge, RAG retrieves relevant documents and uses them as context for generation."}]}}
# ...
